# %% [markdown]
# <img src='../../img/anaconda-logo.png' align='left' style="padding:10px">
# <br>
# *Copyright Continuum 2012-2016 All Rights Reserved.*

# %% [markdown]
# # Bokeh Exercise: Layouts

# %% [markdown]
# ## Table of Contents
# * [Bokeh Exercise: Layouts](#Bokeh-Exercise:-Layouts)
# 	* [Set-Up](#Set-Up)
# * [Exercise](#Exercise)
# * [Solution](#Solution)
# 	* [Read the Data](#Read-the-Data)
# 	* [Create a ColumnDataSource](#Create-a-ColumnDataSource)
# 	* [Create a Figure for `hp` and `mpg`](#Create-a-Figure-for-hp-and-mpg)
# 	* [Create a Figure for `cyl` and `mpg`](#Create-a-Figure-for-cyl-and-mpg)
# 	* [Show the Plots](#Show-the-Plots)

# %% [markdown]
# ## Set-Up

# %%
from bokeh.io import output_notebook, show
output_notebook()

# %% [markdown]
# # Exercise

# %% [markdown]
# * Use the MPG sample data
#     * `data/auto-mpg.csv`
# * Make scatter plots comparing trends in MPG by any two factors
#   * weight, cylinders, horsepower, year, etc.
#   * further, color each data point by its `origin`
# * Link appropriate ranges between the plots and place in a single layout object

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Solution

# %% [markdown]
# ## Read the Data

# %% [markdown]
# Use pandas to read in the data file 'data/auto-mpg.csv':

# %% [markdown]
# ## Create a ColumnDataSource

# %% [markdown]
# Use a dictionary like `{'US':'red','Asia':'blue','Europe':'green'}` to map countries to colors. Apply the map to the `origin` column in the DataFrame generated by reading the `auto-mpg.csv`, storing the result in a new column called `color`

# %%
from bokeh.models import ColumnDataSource

# %% [markdown]
# ## Create a Figure for `hp` and `mpg`

# %%
from bokeh.plotting import figure

# %% [markdown]
# Use the `cicle()` method on Bokeh `figure` object to plot points at points (x,y) defined by `hp` and `mpg` respectively. Use the `color` attribute and the `ColumnDataSource` constructed above.

# %%
# Don't forget to use show( ... )

# %% [markdown]
# ## Create a Figure for `cyl` and `mpg`

# %% [markdown]
# Use the `cicle()` method on Bokeh `figure` object to plot points at points (x,y) defined by `cyl` and `mpg` respectively. Use the `color` attribute and the `ColumnDataSource` constructed above.

# %% [markdown]
# ## Show the Plots

# %% [markdown]
# Plot both of the previous plots on a single figure using `gridplot()` from the `bokeh.layouts` module:

# %%
from bokeh.layouts import gridplot

# %% [markdown]
# ---
# *Copyright Continuum 2012-2016 All Rights Reserved.*
