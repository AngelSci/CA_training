# %% [markdown]
# <img src='../../img/anaconda-logo.png' align='left' style="padding:10px">
# <br>
# *Copyright Continuum 2012-2016 All Rights Reserved.*

# %% [markdown]
# # Bokeh Charts Exercises

# %% [markdown]
# ## Table of Contents
# * [Bokeh Charts Exercises](#Bokeh-Charts-Exercises)
# 	* [Set-Up](#Set-Up)
# * [Box Plots Exercises](#Box-Plots-Exercises)
# * [Bar Chart Exercises](#Bar-Chart-Exercises)
# 	* [Melting DataFrames](#Melting-DataFrames)
# 	* [Plotting the Data](#Plotting-the-Data)
# 	* [Concatenation](#Concatenation)
# 	* [Additional Plot](#Additional-Plot)

# %% [markdown]
# ## Set-Up

# %%
from bokeh.io import output_notebook, show
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="33d48d6c-c565-4783-a6d2-ca8ad3558aba">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# # Box Plots Exercises

# %% [markdown]
# The file `data/Top5000Population.csv` lists the populations of each of the top 5000 most populated cities in the US. Load the data into a DataFrame, and create a new DataFrame containing data only for cities in Maine, South Dakota and Rhode Island.

# %%
import pandas as pd
cities = pd.read_csv('data/Top5000Population.csv', thousands=',', encoding='iso-8859-1')

# %%
cities.head()
# Out:
#            city state  population
# 0     New York     NY     8363710
# 1  Los Angeles     CA     3833995
# 2      Chicago     IL     2853114
# 3      Houston     TX     2242193
# 4      Phoenix     AZ     1567924

# %%
states = cities['state'].isin(['SD','ME','RI'])
subset_cities = cities.loc[states]
subset_cities.head(7)
# Out:
#              city state  population
# 135   Providence     RI      171557
# 149  Sioux Falls     SD      154997
# 339      Warwick     RI       84483
# 372     Cranston     RI       79980
# 434    Pawtucket     RI       71765
# 488   Rapid City     SD       65491
# 514     Portland     ME       62561

# %% [markdown]
# Create a box plot of the `population` data for these three states.
# * Each state has at least one city in this file. Most have many cities.
# * Each bar plot will represent the distribution "across cities", or the distribution of "population sizes" of the cities in that state.

# %%
from bokeh.charts import BoxPlot
plot = BoxPlot(subset_cities, 'state', 'population', color='state')
show(plot)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="b400b749-253e-4ff4-9fe1-fc6628686328"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("b400b749-253e-4ff4-9fe1-fc6628686328");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'b400b749-253e-4ff4-9fe1-fc6628686328' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"226b3c1d-5c20-4ac7-8015-ba9077ea4d40":{"roots":{"references":[{"attributes":{"data_source":{"id":"ad191f21-55ce-4319-b310-3e354e8fba3b","type":"ColumnDataSource"},"glyph":{"id":"5d890efa-4713-4402-92b1-8b97f396c3c6","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"1856354f-c6db-4651-87a7-eceb4efe1df9","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["width","fill_alpha","height","x","label","color","line_alpha","line_color","y"],"data":{"chart_index":[{"state":"RI"}],"color":["#5ab738"],"fill_alpha":[0.8],"height":[21790.75],"label":[{"state":"RI"}],"line_alpha":[1.0],"line_color":["black"],"state":["RI"],"width":[0.8],"x":["RI"],"y":[49227.125]}},"id":"e6c5c53d-2a93-497b-a3ab-a28b318cb748","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"536a7d7c-a7df-4aa2-a491-5965593246c3","type":"Rect"},{"attributes":{"plot":null,"text":null},"id":"ff629162-f9c7-4b61-91b4-2b79e2ad0712","type":"Title"},{"attributes":{"callback":null,"column_names":["width","fill_alpha","height","x","label","color","line_alpha","line_color","y"],"data":{"chart_index":[{"state":"SD"}],"color":["#407ee7"],"fill_alpha":[0.8],"height":[6378.5],"label":[{"state":"SD"}],"line_alpha":[1.0],"line_color":["black"],"state":["SD"],"width":[0.8],"x":["SD"],"y":[16987.25]}},"id":"60dde505-b531-495f-94f5-73a12adb75dc","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x1s","y0s","x0s","y1s"],"data":{"chart_index":[{"state":"RI"},{"state":"RI"},{"state":"RI"},{"state":"RI"}],"state":["RI","RI","RI","RI"],"x0s":["RI:0.5","RI:0.65","RI:0.5","RI:0.65"],"x1s":["RI:0.5","RI:0.35","RI:0.5","RI:0.35"],"y0s":[18683.0,18683.0,81105.75,145266.75],"y1s":[38331.75,18683.0,145266.75,145266.75]}},"id":"f9bef1c0-cbcc-4dd5-be3a-7d44df85b8be","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"5d2efe1b-7190-4ba4-90b6-b7dc209ea498","subtype":"Chart","type":"Plot"}},"id":"3fc6f5e4-cb5f-460c-af18-1bd9ca6b67b2","type":"SaveTool"},{"attributes":{"line_width":{"value":2},"x0":{"field":"x0s"},"x1":{"field":"x1s"},"y0":{"field":"y0s"},"y1":{"field":"y1s"}},"id":"20b4c9bd-60d4-4c10-8e23-5707695f9e84","type":"Segment"},{"attributes":{"data_source":{"id":"8acdcbc7-7b5c-4584-8ad6-5055b91eb0ac","type":"ColumnDataSource"},"glyph":{"id":"7ef7727a-fc5a-4343-ad57-ba84d2791b6f","type":"Circle"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"9243a1ae-d29e-4992-9f10-e2edc50ad6b6","type":"GlyphRenderer"},{"attributes":{"line_width":{"value":2},"x0":{"field":"x0s"},"x1":{"field":"x1s"},"y0":{"field":"y0s"},"y1":{"field":"y1s"}},"id":"8279bd58-4ccd-4fda-8813-3fa3285df44c","type":"Segment"},{"attributes":{},"id":"f3aace28-2a45-4834-8d2a-907d3ffd1353","type":"ToolEvents"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"4d7ef7b5-4ddf-4843-b9d5-1a1d321fc082","type":"PanTool"},{"id":"2f9d19f5-31fa-4499-bad7-887b16298045","type":"WheelZoomTool"},{"id":"8f7a0233-f89d-47d9-a709-3e177b92ca34","type":"BoxZoomTool"},{"id":"3fc6f5e4-cb5f-460c-af18-1bd9ca6b67b2","type":"SaveTool"},{"id":"7401f553-faa3-48f2-afe9-f0a72234dfc8","type":"ResetTool"},{"id":"ab41f283-9992-4f05-b5a8-8f782eeb5eea","type":"HelpTool"}]},"id":"5f46a52e-c476-41fb-b68c-ff5d2e259195","type":"Toolbar"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"5d890efa-4713-4402-92b1-8b97f396c3c6","type":"Rect"},{"attributes":{"line_width":{"value":2},"x0":{"field":"x0s"},"x1":{"field":"x1s"},"y0":{"field":"y0s"},"y1":{"field":"y1s"}},"id":"430cb4d8-a28f-4f7a-8b42 ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[6]</strong>&gt;</code></p>

# %% [markdown]
# # Bar Chart Exercises

# %% [markdown]
# Use the Olympic medals data set at `data/medals_messy.csv`.
#
# Plot the total medals awarded for each county that won at least one medal.
#
# **Hint**: `medals` is a *wide* DataFrame. Bokeh charts prefer *long* DataFrames.

# %%
import pandas as pd
from bokeh.charts.utils import df_from_json
from bokeh.sampledata.olympics2014 import data
medals = df_from_json(data)

# %%
medals.head()
# Out:
#   abbr  bronze  gold  silver  total       name
# 0  ALB       0     0       0      0    Albania
# 1  AND       0     0       0      0    Andorra
# 2  ARG       0     0       0      0  Argentina
# 3  ARM       0     0       0      0    Armenia
# 4  AUS       1     0       2      3  Australia

# %% [markdown]
# ## Melting DataFrames

# %% [markdown]
# Use pandas `melt` to reduce the three columns `gold`, `silver`, and `bronze`, into one column `medal` which contains string values `gold`, `silver`, and `bronze`.

# %%
df = pd.melt(medals, 
             id_vars='name', 
             value_vars=['bronze','silver','gold'], 
             var_name='medal', value_name='count')
df.head()
df.sort_values('count', ascending=False)
# Out:
#                        name   medal  count
# 81            United States  bronze     10
# 54              Netherlands  bronze      8
# 152            Russian Fed.  silver      8
# 100                  Canada  silver      8
# 201                 Germany    gold      8
# 230                  Norway    gold      8
# 56                   Norway  bronze      7
# 65             Russian Fed.  bronze      7
# 141             Netherlands  silver      6
# 239            Russian Fed.    gold      6
# 228             Netherlands    gold      6
# 246             Switzerland    gold      6
# 255           United States    gold      6
# 92                  Austria  silver      6
# 25                   France  bronze      5
# 181                 Belarus    gold      5
# 158                  Sweden  silver      5
# 27                  Germany  bronze      4
# 36                    Italy  bronze      4
# 125                   Japan  silver      4
# 168           United States  silver      4
# 69                 Slovenia  bronze      4
# 13                   Canada  bronze      4
# 143                  Norway  silver      4
# 187                  Canada    gold      4
# 235                  Poland    gold      4
# 114                 Germany  silver      3
# 111                 Finland  silver      3
# 107          Czech Republic  silver      3
# 199                  France    gold      3
# ..                      ...     ...    ...
# 146                    Peru  silver      0
# 116                  Greece  silver      0
# 113                 Georgia  silver      0
# 77                     Togo  bronze      0
# 93               Azerbaijan  silver      0
# 78                    Tonga  bronze      0
# 79                   Turkey  bronze      0
# 82               Uzbekistan  bronze      0
# 83                Venezuela  bronze      0
# 84            Virgin Isl, B  bronze      0
# 85           Virgin Isl, Us  bronze      0
# 86                 Zimbabwe  bronze      0
# 87                  Albania  silver      0
# 88                  Andorra  silver      0
# 89                Argentina  silver      0
# 90                  Armenia  silver      0
# 94                  Belarus  silver      0
# 110                 Estonia  silver      0
# 95                  Belgium  silver      0
# 96                  Bermuda  silver      0
# 97   Bosnia And Herzegovina  silver      0
# 98                   Brazil  silver      0
# 99                 Bulgaria  silver      0
# 101          Cayman Islands  silver      0
# 102                   Chile  silver      0
# 104          Chinese Taipei  silver      0
# 106                  Cyprus  silver      0
# 108                 Denmark  silver      0
# 109                Dominica  silver      0
# 260                Zimbabwe    gold      0
#
# [261 rows x 3 columns]

# %% [markdown]
# ## Plotting the Data

# %% [markdown]
# Create a bar chart using only data for which `count` is 1 or higher. Plot the total count of medals (vertical) versus the country names (horizontal). Stack the bars using the `medal` column.

# %%
from bokeh.charts import Bar
plot = Bar( df[df['count']>0], 
            label='name', 
            values='count', 
            stack='medal', 
           legend=True)
show(plot)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="1d4d296d-7c80-40fd-a614-3f4b8069d364"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("1d4d296d-7c80-40fd-a614-3f4b8069d364");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '1d4d296d-7c80-40fd-a614-3f4b8069d364' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"c5e70f4c-47b5-45a8-b20a-39047a686c40":{"roots":{"references":[{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"18aa9386-28d6-465a-ac53-36bcf934f0d5","type":"Rect"},{"attributes":{"callback":null,"column_names":["width","fill_alpha","height","x","label","color","line_alpha","line_color","y"],"data":{"chart_index":[{"medal":"bronze","name":"Japan"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[2.0],"label":[{"medal":"bronze","name":"Japan"}],"line_alpha":[1.0],"line_color":["white"],"medal":["bronze"],"name":["Japan"],"width":[0.8],"x":["Japan"],"y":[1.0]}},"id":"3998b3c5-aa52-4320-8833-dc93c4c3bd7a","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"47baf1e9-96fe-4356-8a32-6761060d4274","type":"ColumnDataSource"},"glyph":{"id":"db207857-47cb-4fb0-bdbd-8f3f85a3c3dd","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"e843a565-5324-4981-af8a-6b2683a5cb43","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"c89d388d-c82e-4eeb-aadc-dbb2c9664447","type":"Rect"},{"attributes":{"plot":{"id":"fa6df02b-7ef8-445a-a5a0-128aa476b139","subtype":"Chart","type":"Plot"}},"id":"54d2fdd8-7fa8-4c2d-a560-4e5635f3af56","type":"HelpTool"},{"attributes":{"data_source":{"id":"870a1aa7-c777-40c2-a7b1-e83b5c2a1b9e","type":"ColumnDataSource"},"glyph":{"id":"4f7e5477-8410-4b46-aabf-492c3811fe0f","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"91fd5b9b-653b-46ea-a00d-9070eca87880","type":"GlyphRenderer"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"f48fcfd8-cb20-4a55-b1c1-bdeb5dc67879","type":"BoxAnnotation"},{"attributes":{"data_source":{"id":"02cf10e8-55e1-4171-bcb6-7fa4aca03f6c","type":"ColumnDataSource"},"glyph":{"id":"9c9dc13a-de42-4289-9ee0-b4584cb306c6","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"8dca5e0f-6d7f-4346-b37f-1434b720baa1","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["width","fill_alpha","height","x","label","color","line_alpha","line_color","y"],"data":{"chart_index":[{"medal":"bronze","name":"Ukraine"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[1.0],"label":[{"medal":"bronze","name":"Ukraine"}],"line_alpha":[1.0],"line_color":["white"],"medal":["bronze"],"name":["Ukraine"],"width":[0.8],"x":["Ukraine"],"y":[0.5]}},"id":"1f0725b9-40bb-4132-ad0d-fa6e5bd33ba2","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["width","fill_alpha","height","x","label","color","line_alpha","line_color","y"],"data":{"chart_index":[{"medal":"gold","name":"Czech Republic"}],"color":["#5ab738"],"fill_alpha":[0.8],"height":[1.0],"label":[{"medal":"gold","name":"Czech Republic"}],"line_alpha":[1.0],"line_color":["white"],"medal":["gold"],"name":["Czech Republic"],"width":[0.8],"x":["Czech Republic"],"y":[5.5]}},"id":"be83322a-662d-4cc9-affb-217583ec0192","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["width","fill_alpha","height","x","label","color","line_alpha","line_color","y"],"data":{"chart_index":[{"medal":"gold","name":"Slovakia"}],"color":["#5ab738"],"fill_alpha":[0.8],"height":[1.0],"label":[{"medal":"gold","name":"Slovakia"}],"line_alpha":[1.0],"line_color":["white"],"medal":["gold"],"name":["Slovakia"],"width":[0.8],"x":["S ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[14]</strong>&gt;</code></p>

# %% [markdown]
# ## Concatenation

# %% [markdown]
# Even better would be if we had only 3 rows for each country, one for each medal type, and a new column "count" that listed the total count of that medal type. Create a new DataFrame that contains precisely that structure:

# %%
dfs = []
for i in ['bronze', 'silver', 'gold']:
    tmp = medals.loc[medals['total']>0, [i, 'name']].copy()
    tmp['medal'] = i
    tmp = tmp.rename(columns={i:'count'})
    dfs.append(tmp)
long_df = pd.concat(dfs)
long_df.head(15)

# %% [markdown]
# ## Additional Plot

# %% [markdown]
# Use the new DataFrame generated above to create a new stacked bar chart, again using `medal` column to stack.

# %%
from bokeh.charts import Bar
plot = Bar(long_df, label='name', values='count', stack='medal', legend=True)
show(plot)

# %% [markdown]
# See the [Bokeh Gallery](http://bokeh.pydata.org/en/0.11.1/docs/gallery/stacked_bar_chart.html) for another solution.

# %% [markdown]
# ---
#
# *Copyright Continuum 2012-2016 All Rights Reserved.*
