# %%
import arcgis
import pandas as pd

# %%
#pd.DataFrame(dir(arcgis.gis))

# %% [markdown]
# Chef - automate infrastructure - published on github for download.
# https://supermarket.chefio/cookbooks/arcgis
# https://github.com/esri/arcgis-cookbook

# %% [markdown]
# https://developers.arcgis.com/python/
#
# Gives access to analytic capabilities.

# %%
from arcgis import gis as gis

# %%
my_gis = gis.GIS()

# %% [markdown]
# ### DEMOS
#
# Problem need to set up webgis platform loaded w users and contents
#
# A. Run chef automation scripts to set up a web GIS
# Chef is a powerful scripting tool

# %%
from arcgis.gis import *
from IPython.display import display

# %%
gis = GIS()

# %%
#gis.groups.create_from_dict() --adds users from a dictionary

# %%
import os

# %%
#gis = GIS('https://arcgis.com','arcgis_python','P@ssword123') - example of how to connect

# %%
#gis.content.add({},data_dir + current_data)

# %%
gis.properties
# Out:
# {
#   "httpPort": 80,
#   "httpsPort": 443,
#   "helperServices": {
#     "asyncClosestFacility": {
#       "url": "https://logistics.arcgis.com/arcgis/rest/services/World/ClosestFacility/GPServer/FindClosestFacilities",
#       "defaultTravelMode": "FEgifRtFndKNcJMJ"
#     },
#     "defaultElevationLayers": [
#       {
#         "url": "https://elevation3d.arcgis.com/arcgis/rest/services/WorldElevation3D/Terrain3D/ImageServer",
#         "layerType": "ArcGISTiledElevationServiceLayer",
#         "id": "globalElevation"
#       }
#     ],
#     "asyncLocationAllocation": {
#       "url": "https://logistics.arcgis.com/arcgis/rest/services/World/LocationAllocation/GPServer",
#       "defaultTravelMode": "FEgifRtFndKNcJMJ"
#     },
#     "traffic": {
#       "url": "https://traffic.arcgis.com/arcgis/rest/services/World/Traffic/MapServer"
#     },
#     "route": {
#       "url": "https://route.arcgis.com/arcgis/rest/services/World/Route/NAServer/Route_World",
# ...

# %%
from IPython.display import YouTubeVideo

# %% [markdown]
# http://esri.github.io/arcgis-python-api/apidoc/html/
